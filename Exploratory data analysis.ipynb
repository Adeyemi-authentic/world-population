# %% [markdown]
# ### Exploratory data analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
# to change the numbers to 2 dec place

# %%
df.set_option('display.float_format',lambda x:'%.2f' % x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4348\1513915927.py in ?()
# ----> 1 df.set_option('display.float_format',lambda x:'%.2f' % x)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_option'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
# to check for null

df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country/Territory              234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
# to sort the data based on 2022 population, top 5

# %%
df.sort_values(by='2022 Population', ascending=False).head(10)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
 df2=df.sort_values(by='World Population Percentage', ascending=False).head(10)

# %%
df2
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
df2.corr(method='Pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df2.corr(method='Pearson')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df[df['Continent']=='Oceania']
# Out:
#      Rank CCA3         Country/Territory       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df.groupby('Continent')

# %%
df.groupby('Continent').count()
# Out:
#                Rank  CCA3  Country/Territory  Capital  2022 Population  \
# Continent
# Africa           57    57                 57       57               57
# Asia             50    50                 50       50               50
# Europe           50    50                 50       50               50
# North America    40    40                 40       40               40
# Oceania          23    23                 23       23               23
# South America    14    14                 14       14               14
#
#                2020 Population  2015 Population  2010 Population  \
# Continent
# Africa                      57               57               57
# Asia                        50               50               50
# Europe                      50               50               50
# North America               40               40               40
# Oceania                     23               23               23
# ...

# %%
df.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
       'Growth Rate', 'World Population Percentage']].mean().sort_values(by='2022 Population', ascending=False)
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia              9.442767e+07     9.326173e+07     8.916500e+07
# South America     3.120119e+07     3.082357e+07     2.950960e+07
# Africa            2.503037e+07     2.387144e+07     2.107197e+07
# North America     1.500740e+07     1.485591e+07     1.425960e+07
# Europe            1.486295e+07     1.491584e+07     1.483071e+07
# Oceania           1.958198e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.440083e+07     7.470179e+07     6.421127e+07
# South America     2.807702e+07     2.497388e+07     2.122474e+07
# Africa            1.851277e+07     1.436747e+07     1.119563e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Europe            1.471228e+07     1.452187e+07     1.440642e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
#
# ...

# %%
df.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
       'Growth Rate', 'World Population Percentage']].min()
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa                  107118           105530            99240
# Asia                    449002           441725           421437
# Europe                     510              520              564
# North America             4390             4500             5059
# Oceania                   1871             1827             1454
# South America             3780             3747             3408
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa                   92409            80060            71057
# Asia                    361575           282507           224957
# Europe                     596              651              700
# North America             4938             5138             5168
# Oceania                   1367             1666             1669
# South America             3187             3080             2332
#
# ...

# %%
df.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
       'Growth Rate', 'World Population Percentage']].mean()
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa            2.503037e+07     2.387144e+07     2.107197e+07
# Asia              9.442767e+07     9.326173e+07     8.916500e+07
# Europe            1.486295e+07     1.491584e+07     1.483071e+07
# North America     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania           1.958198e+06     1.910149e+06     1.756664e+06
# South America     3.120119e+07     3.082357e+07     2.950960e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.851277e+07     1.436747e+07     1.119563e+07
# Asia              8.440083e+07     7.470179e+07     6.421127e+07
# Europe            1.471228e+07     1.452187e+07     1.440642e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# South America     2.807702e+07     2.497388e+07     2.122474e+07
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
# to plot the values

# %%
df3=df.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
       'Growth Rate', 'World Population Percentage']]

# %%
df3

# %%
df3.plot()
# Out:
# Continent
# Africa           Axes(0.125,0.11;0.775x0.77)
# Asia             Axes(0.125,0.11;0.775x0.77)
# Europe           Axes(0.125,0.11;0.775x0.77)
# North America    Axes(0.125,0.11;0.775x0.77)
# Oceania          Axes(0.125,0.11;0.775x0.77)
# South America    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# to change the rows to columns and columns to rows

# %%
df3=df.groupby('Continent')[['2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population', '1990 Population',
       '1980 Population', '1970 Population', 'World Population Percentage']]

# %%
df3

# %%
df3.transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df3.transpose()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'transpose'

# %%
new=df[['Continent','2022 Population', '2020 Population', '2015 Population',
       '2010 Population', '2000 Population']]

# %%
new
# Out:
#     Continent  2022 Population  2020 Population  2015 Population  \
# 0        Asia         41128771         38972230         33753499
# 1      Europe          2842321          2866849          2882481
# 2      Africa         44903225         43451666         39543154
# 3     Oceania            44273            46189            51368
# 4      Europe            79824            77700            71746
# ..        ...              ...              ...              ...
# 229   Oceania            11572            11655            12182
# 230    Africa           575986           556048           491824
# 231      Asia         33696614         32284046         28516545
# 232    Africa         20017675         18927715         16248230
# 233    Africa         16320537         15669666         14154937
#
#      2010 Population  2000 Population
# 0           28189672         19542982
# 1            2913399          3182021
# 2           35856344         30774621
# ...

# %%
new.groupby('Continent')

# %%
new_d=new.groupby('Continent')

# %%
new_d.max()
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa               218541212        208327405        183995785
# Asia                1425887337       1424929781       1393715448
# Europe               144713314        145617329        144668389
# North America        338289857        335942003        324607776
# Oceania               26177413         25670051         23820236
# South America        215313498        213196304        205188205
#
#                2010 Population  2000 Population
# Continent
# Africa               160952853        122851984
# Asia                1348191368       1264099069
# Europe               143242599        146844839
# North America        311182845        282398554
# Oceania               22019168         19017963
# South America        196353492        175873720

# %%
new_grp=new_d.max()

# %%
new_grp.transpose()
# Out:
# Continent           Africa        Asia     Europe  North America   Oceania  \
# 2022 Population  218541212  1425887337  144713314      338289857  26177413
# 2020 Population  208327405  1424929781  145617329      335942003  25670051
# 2015 Population  183995785  1393715448  144668389      324607776  23820236
# 2010 Population  160952853  1348191368  143242599      311182845  22019168
# 2000 Population  122851984  1264099069  146844839      282398554  19017963
#
# Continent        South America
# 2022 Population      215313498
# 2020 Population      213196304
# 2015 Population      205188205
# 2010 Population      196353492
# 2000 Population      175873720

# %%
df4=new_grp.transpose()

# %%
df4.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
# another way to remove the strin or object in the data

# %%
df.select_dtypes(include='number') # we can now name the dataframe
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36         41128771         38972230         33753499         28189672
# 1     138          2842321          2866849          2882481          2913399
# 2      34         44903225         43451666         39543154         35856344
# 3     213            44273            46189            51368            54849
# 4     203            79824            77700            71746            71519
# ..    ...              ...              ...              ...              ...
# 229   226            11572            11655            12182            13142
# 230   172           575986           556048           491824           413296
# 231    46         33696614         32284046         28516545         24743946
# 232    63         20017675         18927715         16248230         13792086
# 233    74         16320537         15669666         14154937         12839771
#
# ...

# %%
#if we want to show only objects or string

# %%
df.select_dtypes(include='object')
# Out:
#     CCA3  Country/Territory           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
# otherwise we can just follow the previous method by selecting the columns
